# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('data/apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **1**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                                          App             Category  Rating  \
# 6875   Univision NOW - Live TV and On Demand        ENTERTAINMENT    4.00
# 1687                              CX watcher               FAMILY    4.50
# 4853          Rainbow - Journal & Activities            PARENTING    4.80
# 419                         Guide for IMS DB  BOOKS_AND_REFERENCE     NaN
# 10735                               Snapchat               SOCIAL    4.00
#
#         Reviews  Size_MBs     Installs  Type Price Content_Rating  \
# 6875      22998      9.35    1,000,000  Free     0           Teen
# 1687          4     30.00          500  Free     0       Everyone
# 4853       6668     20.00      100,000  Free     0       Everyone
# 419           0      2.60           10  Free     0       Everyone
# 10735  17014787      5.30  500,000,000  Free     0           Teen
#
#                   Genres    Last_Updated         Android_Ver
# 6875       Entertainment   June 27, 2018  Varies with device
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **2**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
# df_apps=df_apps.drop('Last_Updated', axis=1)
# df_apps=df_apps.drop('Android_Ver', axis=1)
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **3**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df` that does not include these rows.

# %%
df_apps.isna().values.sum()
# Out:
# np.int64(1477)

# %%
df=df_apps.dropna()
df.isna().values.sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **4**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df`.

# %%
df.duplicated().sum()
# Out:
# np.int64(474)

# %%
df=df.drop_duplicates(subset='App')
# df[df['App'] == 'Instagram']
df.shape
# Out:
# (8195, 12)

# %% [markdown]
# # Find Highest Rated Apps
#
# **5**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df[df['Rating'] == df['Rating'].max()]['App'].reset_index()#5.0
# Out:
#      index                                               App
# 0       21                               KBA-EZ Health Guide
# 1       28                                          Ra Ga Ba
# 2       47                                           Mu.F.O.
# 3       82                                  Brick Breaker BR
# 4       99   Anatomy & Physiology Vocabulary Exam Review App
# ..     ...                                               ...
# 266   2680                               Florida Wildflowers
# 267   2750  Superheroes, Marvel, DC, Comics, TV, Movies News
# 268   3030           CL Keyboard - Myanmar Keyboard (No Ads)
# 269   3115                                        Oración CX
# 270   4058                          Ek Bander Ne Kholi Dukan
#
# [271 rows x 2 columns]

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **7**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df[df['Size_MBs'] == df['Size_MBs'].max()]['App'].reset_index()#100mb
# Out:
#     index                                               App
# 0    1795                              Navi Radiography Pro
# 1    3144                                        Vi Trainer
# 2    4176  Car Crash III Beam DH Real Damage Simulator 2018
# 3    7926                                         Post Bank
# 4    7927                       The Walking Dead: Our World
# 5    7928                     Stickman Legends: Shadow Wars
# 6    8718                 Mini Golf King - Multiplayer Game
# 7    8719                        Draft Simulator for FUT 18
# 8    9942                    Talking Babsy Baby: Baby Games
# 9    9943                             Miami crime simulator
# 10   9944                      Gangster Town: Vice District
# 11   9945                                   Ultimate Tennis
# 12  10295                                   SimCity BuildIt
# 13  10687                            Hungry Shark Evolution

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **8**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df.sort_values('Reviews', ascending=False).head(10)
# Out:
#                                                      App       Category  \
# 10805                                           Facebook         SOCIAL
# 10785                                 WhatsApp Messenger  COMMUNICATION
# 10806                                          Instagram         SOCIAL
# 10784           Messenger – Text and Video Chat for Free  COMMUNICATION
# 10650                                     Clash of Clans           GAME
# 10744            Clean Master- Space Cleaner & Antivirus          TOOLS
# 10835                                     Subway Surfers           GAME
# 10828                                            YouTube  VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 10584                                       Clash Royale           GAME
#
#        Rating   Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805    4.10  78158306      5.30  1,000,000,000  Free     0           Teen
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings=df.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6617
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
import plotly.express as px

# %%
fig= px.pie(labels=ratings.index,values=ratings.values,title="Content Rating",names=ratings.index)

fig.update_traces(textposition='outside', textinfo='percent+label')

fig.show()

# %%
fig= px.pie(labels=ratings.index,values=ratings.values,title="Content Rating",names=ratings.index,hole=0.5)# adding hole size

fig.update_traces(textposition='outside', textinfo='percent+label')

fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **9**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
instals_df=df['Installs'].value_counts()
instals_df
# Out:
# Installs
# 1,000,000        1417
# 100,000          1095
# 10,000            987
# 10,000,000        933
# 1,000             697
# 5,000,000         607
# 500,000           504
# 50,000            457
# 5,000             425
# 100               303
# 50,000,000        202
# 500               199
# 100,000,000       188
# 10                 69
# 50                 56
# 500,000,000        24
# 1,000,000,000      20
# 5                   9
# 1                   3
# Name: count, dtype: int64

# %%
df.Installs = df.Installs.astype(str).str.replace(',', "")
df.Installs = pd.to_numeric(df.Installs)
df[['App', 'Installs']].groupby('Installs',).count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         697
# 5000         425
# 10000        987
# 50000        457
# 100000      1095
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    188
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **10**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df.Price = df.Price.astype(str).str.replace('$', "")
df.Price = pd.to_numeric(df.Price)
df[['App', 'Price']].groupby('Price',).count()
# Out:
#          App
# Price
# 0.00    7592
# 0.99     104
# 1.00       2
# 1.20       1
# 1.29       1
# ...      ...
# 299.99     1
# 379.99     1
# 389.99     1
# 399.99    11
# 400.00     1
#
# [73 rows x 1 columns]

# %% [markdown]
# ### The most expensive apps sub $250

# %%
# df[df['Price'] >=250]
df = df[df['Price'] < 250]
# df[df['Price'] <250]

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df['Revenue_Estimate'] = df['Price'] * df['Installs']
df
# Out:
#                                                    App            Category  \
# 21                                 KBA-EZ Health Guide             MEDICAL
# 28                                            Ra Ga Ba                GAME
# 47                                             Mu.F.O.                GAME
# 82                                    Brick Breaker BR                GAME
# 99     Anatomy & Physiology Vocabulary Exam Review App             MEDICAL
# ...                                                ...                 ...
# 10824                                     Google Drive        PRODUCTIVITY
# 10828                                          YouTube       VIDEO_PLAYERS
# 10829                          Google Play Movies & TV       VIDEO_PLAYERS
# 10831                                      Google News  NEWS_AND_MAGAZINES
# 10835                                   Subway Surfers                GAME
#
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
cat_number = df.groupby('Category').agg({'App': pd.Series.count})
category_installs = df.groupby('Category').agg({'Installs': pd.Series.sum})
cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how="inner")

cat_merged_df.sort_values('Installs', ascending=False).head()
# Out:
#                App     Installs
# Category
# GAME           910  13858762717
# COMMUNICATION  257  11039241530
# TOOLS          718   7999724500
# PRODUCTIVITY   301   5788070180
# SOCIAL         203   5487841475

# %%
scatter = px.scatter(cat_merged_df, x='App', y='Installs', title='Category Concentration', size='App', hover_name='App', color='Installs')
scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)", yaxis_title="Installs", yaxis=dict(type='log'))

scatter.show()

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **11**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
stack = df.Genres.str.split(';', expand=True).stack()

num_genres = stack.value_counts().reset_index()
num_genres
# Out:
#                       index  count
# 0                     Tools    718
# 1                 Education    587
# 2             Entertainment    498
# 3                    Action    304
# 4              Productivity    301
# 5                 Lifestyle    298
# 6           Personalization    296
# 7                   Finance    296
# 8                   Medical    291
# 9                    Sports    270
# 10              Photography    263
# 11                 Business    262
# 12            Communication    258
# 13         Health & Fitness    245
# 14                   Casual    216
# 15         News & Magazines    204
# 16                   Social    203
# 17               Simulation    200
# 18           Travel & Local    187
# 19                   Arcade    185
# 20                 Shopping    180
# 21        Books & Reference    171
# 22  Video Players & Editors    150
# 23                   Dating    134
# 24                   Puzzle    124
# 25        Maps & Navigation    118
# ...

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **12**: Can you create this chart with the Series containing the genre data?
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar = px.bar(num_genres[:15], x='index', y='count', title='Top Genres', hover_name='index', color='count', color_continuous_scale='Agsunset')
bar.update_layout(xaxis_title='index', yaxis_title='Number of Apps', coloraxis_showscale=False)
 
bar.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_free_vs_paid = df.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
g_bar = px.bar(df_free_vs_paid,x='Category',y='App',title='Free vs Paid Apps by Category',color='Type',barmode='group')
 
g_bar.update_layout(xaxis_title='Category',yaxis_title='Number of Apps',xaxis={'categoryorder':'total descending'},yaxis=dict(type='log'))
 
g_bar.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **13**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.

# %%
box = px.box(df_apps,y='Installs',x='Type',color='Type',notched=True,points='all',title='How Many Downloads are Paid Apps Giving Up?')
 
box.update_layout(yaxis=dict(type='log'))
 
box.show()

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **14**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df[df['Type'] == 'Paid']
box = px.box(df_paid_apps, x='Category', y='Revenue_Estimate',title='How Much Can Paid Apps Earn?')

box.update_layout(xaxis_title='Category', yaxis_title='Paid App Ballpark Revenue',xaxis={'categoryorder':'min ascending'},yaxis=dict(type='log'))
 
box.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **15**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
df_paid_apps.Price.median()
# Out:
# np.float64(2.99)

# %%
box = px.box(df_paid_apps,x='Category',y="Price",title='Price per Category')
 
box.update_layout(xaxis_title='Category', yaxis_title='Paid App Price',xaxis={'categoryorder':'max descending'}, yaxis=dict(type='log'))
 
box.show()
